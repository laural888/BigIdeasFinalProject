# %% [markdown]
# # Top 10 Safest Neighborhoods in Pittsburgh
#
# For my part of the project, I wanted to look at the safety aspect of the neighborhoods. After going through a couple of data sets from the Western Pennsylvania
# Regional Data Center, I found one which showed a list of police incidents of crime in various neighborhoods throughout Pittsburgh. I felt that this would be a perfect data set to get an idea of where there is more crime in addition to where there are more harsher crimes. Through that data, I was able to come across the top 10 safest neighborhoods in Pittsburgh through creating a weight or value for each neighborhood based on the number and severity of the incidents and identifying the neighborhoods with the smallest weight.

# %%
# imported pandas to use
import pandas as pd

# accessed the data set I was using
safety = pd.read_csv("PoliceIncidents.csv") 
safety.head()
# Out:
#    _id       PK         CCR  HIERARCHY         INCIDENTTIME  \
# 0    1  2802309  16000001.0         10  2016-01-01T00:00:00
# 1    2  2803174  16004547.0         11  2016-01-01T00:01:00
# 2    3  2801809  16000367.0          4  2016-01-01T00:10:00
# 3    4  2802315  16000035.0         10  2016-01-01T00:15:00
# 4    5  2802312  16000024.0          4  2016-01-01T00:16:00
#
#                                 INCIDENTLOCATION CLEAREDFLAG  \
# 0  400 Block North Shore DR Pittsburgh, PA 15212           Y
# 1    5400 Block Carnegie ST Pittsburgh, PA 15201           N
# 2  500 Block Mt Pleasant RD Pittsburgh, PA 15214           N
# 3         300 Block Wood ST Pittsburgh, PA 15222           Y
# 4  500 Block Mt Pleasant RD Pittsburgh, PA 15214           N
#
#           INCIDENTNEIGHBORHOOD INCIDENTZONE  \
# 0                  North Shore            1
# 1          Upper Lawrenceville            2
# 2            Northview Heights            1
# 3  Golden Triangle/Civic Arena            2
# 4            Northview Heights            1
#
#                       INCIDENTHIERARCHYDESC  \
# 0            HARRASSMENT/THREAT/ATTEMPT/PHY
# 1                        THEFT BY DECEPTION
# 2   DISCHARGE OF FIREARM INTO OCC.STRUCTURE
# 3            HARRASSMENT/THREAT/ATTEMPT/PHY
# 4  PROP MISSILE INTO OCC VEHICLE/OR ROADWAY
#
#                                             OFFENSES  INCIDENTTRACT  \
# 0  2702 Aggravated Assault. / 2709(a) Harassment....         2205.0
# 1                           3922 Theft by Deception.         1011.0
# 2  2707.1 Discharge of a Firearm into Occupied St...         2609.0
# 3        2709(a)(3) Harassment No Legitimate Purpose          201.0
# 4  2705 Recklessy Endangering Another Person. / 3...         2609.0
#
#    COUNCIL_DISTRICT  PUBLIC_WORKS_DIVISION          X          Y
# 0               1.0                    6.0 -80.012337  40.446263
# 1               7.0                    2.0 -79.950295  40.482290
# 2               1.0                    1.0 -80.000966  40.478651
# 3               6.0                    6.0 -80.001251  40.438918
# 4               1.0                    1.0 -80.000966  40.478651

# %%
# deleted all the columns except the neighborhoods and the incidents
safety = safety[['INCIDENTNEIGHBORHOOD','INCIDENTHIERARCHYDESC']]
safety.head(20)
# Out:
#            INCIDENTNEIGHBORHOOD                     INCIDENTHIERARCHYDESC
# 0                   North Shore            HARRASSMENT/THREAT/ATTEMPT/PHY
# 1           Upper Lawrenceville                        THEFT BY DECEPTION
# 2             Northview Heights   DISCHARGE OF FIREARM INTO OCC.STRUCTURE
# 3   Golden Triangle/Civic Arena            HARRASSMENT/THREAT/ATTEMPT/PHY
# 4             Northview Heights  PROP MISSILE INTO OCC VEHICLE/OR ROADWAY
# 5              South Side Flats                         PUBLIC DRUNKENESS
# 6                       Elliott                  AGG ASSAULT/OTHER/INJURY
# 7              South Side Flats                         PUBLIC DRUNKENESS
# 8                Homewood North            HARRASSMENT/THREAT/ATTEMPT/PHY
# 9             South Side Slopes                    BURGLARY/FORCE ENT/RES
# 10             South Side Flats                         LIQUOR LAWS-OTHER
# 11               Homewood North             RECKLESSLY ENDANGER ANOTH PER
# 12                  North Shore                     SIMPLE ASSAULT/INJURY
# 13  Golden Triangle/Civic Arena                         PUBLIC DRUNKENESS
# 14                      Carrick                                       NaN
# 15                South Oakland  PROP MISSILE INTO OCC VEHICLE/OR ROADWAY
# 16                          NaN                         INDECENT EXPOSURE
# 17                   Bloomfield                  AGG ASSAULT/KNIFE/INJURY
# 18                    Beechview                                       NaN
# 19  Golden Triangle/Civic Arena                       THEFT FROM BUILDING

# %%
# created a DataFrame for just storing the neighborhoods in Pittsburgh
neighborhoods = safety[['INCIDENTNEIGHBORHOOD']].copy()
neighborhoods.head()
# Out:
#           INCIDENTNEIGHBORHOOD
# 0                  North Shore
# 1          Upper Lawrenceville
# 2            Northview Heights
# 3  Golden Triangle/Civic Arena
# 4            Northview Heights

# %%
# deleted all the duplicate neighborhoods from the original data set and created a finalized list of neighborhoods in Pittsburgh
neighborhoods = neighborhoods.drop_duplicates(ignore_index=True)
print(neighborhoods)
# Out:
#            INCIDENTNEIGHBORHOOD
# 0                   North Shore
# 1           Upper Lawrenceville
# 2             Northview Heights
# 3   Golden Triangle/Civic Arena
# 4              South Side Flats
# ..                          ...
# 94              Mt. Oliver Boro
# 95    Central Business District
# 96                    Troy Hill
# 97           Central North Side
# 98                 Mount Oliver
#
# [99 rows x 1 columns]

# %%
# created a DataFrame to just store all the possible incidents that have occurred getting rid of the duplicates from the original data set
incidents = safety[['INCIDENTHIERARCHYDESC']].copy()
incidents.drop_duplicates(ignore_index=True)

# displayed a new column that kept count on the number of duplicates for each incident in the data set
incidents.groupby(incidents.columns.tolist(),as_index=False).size().sort_values(by="size", ascending=False).head(40)
# Out:
#               INCIDENTHIERARCHYDESC   size
# 281                 THEFT FROM AUTO  17451
# 288                THEFT/ALL OTHERS  15314
# 266           SIMPLE ASSAULT/INJURY  12663
# 91         CRIMINAL MISCHIEF (AUTO)  11395
# 214      RETAIL THEFT (SHOPLIFTING)   8963
# 137  HARRASSMENT/THREAT/ATTEMPT/PHY   8694
# 90                CRIMINAL MISCHIEF   8455
# 174            MTR VEH THEFT (AUTO)   6885
# 136               HARRASSMENT-OTHER   5777
# 135    HARRASSMENT BY COMUN/ADDRESS   5076
# 162               MARIJUANA-POSSESS   4948
# 276             TERRORISTIC THREATS   4462
# 66           BURGLARY/FORCE ENT/RES   4372
# 290     THEFT/PROP-LOST/MISLAID/DEL   4276
# 68            BURGLARY/NO FORCE/RES   4107
# 139                  IDENTITY THEFT   4105
# 29   ALL OTHER OFFENSES(EXPT TRAFF)   3902
# 204               PUBLIC DRUNKENESS   3886
# 103         DRIVING UNDER INFLUENCE   3715
# 84                     CREDIT CARDS   3467
# 279              THEFT BY DECEPTION   3314
# 267        SIMPLE ASSAULT/NO INJURY   3073
# 190      OPIUM/COCAINE/DERV-POSSESS   2831
# 282             THEFT FROM BUILDING   2810
# 92                CRIMINAL TRESPASS   2431
# 87         CRIM MISCHIEF (GRAFFITI)   2391
# 101              DISORDERLY CONDUCT   2207
# 203               PROTECTIVE ORDERS   2163
# 311         WEAPONS-CARRY/POS-OTHER   2097
# 213  RESIST ARREST/OTHER LAW ENFORC   2039
# 239       ROBBERY/HIGHWAY/STRONGARM   2031
# 278                  THEFT BICYCLES   1806
# 106              DRUG PARAPHERNALIA   1581
# 211   RECKLESSLY ENDANGER ANOTH PER   1472
# 189    OPIUM/COCAINE/DERV(SALE/MFG)   1460
# 167   MOTOR THEFT (AUTO)-PLATE ONLY   1388
# 65       BURGLARY/FORCE ENT/NON-RES   1360
# 7          AGG ASSAULT/OTHER/INJURY   1337
# 209       RECEIVING STOLEN PROPERTY   1336
# 9      AGG ASSAULT/STRONGARM/INJURY   1310

# %% [markdown]
# ### Weights for the top 10 most relevant incidents + murder
# The weights for the ten most relevant incidents which is found from the number of times each type of incident has occurred in Pittsburgh in addition to murder.
#
# **THEFT FROM AUTO** = 8
#
# **THEFT/ALL OTHERS** = 8
#
# **SIMPLE ASSAULT/INJURY** = 15
#
# **CRIMINAL MISCHIEF (AUTO)** = 5
#
# **RETAIL THEFT (SHOPLIFTING)** = 5
#
# **HARRASSMENT/THREAT/ATTEMPT/PHY** = 15
#
# **CRIMINAL MISCHIEF** = 5
#
# **MTR VEH THEFT (AUTO)** = 8
#
# **HARRASSMENT-OTHER** = 10
#
# **HARRASSMENT BY COMUN/ADDRESS** = 10
#
# **MURDER/NON-NEG/MANSLTR-OTHER** = 20
#
# **OTHER** = 2

# %%
# a dictionary is created to keep count of the value for the weight for each neighborhood
weight = 0
count = dict()

# loops through the entire original data set to figure out the incidents that have happened in each neighborhood
for row in range(len(safety)):
    current = safety.loc[row, "INCIDENTHIERARCHYDESC"]
    neighbrhd = safety.loc[row, "INCIDENTNEIGHBORHOOD"]
    
    # a value is given for a weight based on the severity of the crime
    if current in ["THEFT FROM AUTO", "THEFT/ALL OTHERS", "MTR VEH THEFT (AUTO)"]:
        weight = 8
    elif current in ["SIMPLE ASSAULT/INJURY", "HARRASSMENT/THREAT/ATTEMPT/PHY"]:
        weight = 15
    elif current in ["CRIMINAL MISCHIEF (AUTO)", "RETAIL THEFT (SHOPLIFTING)", "CRIMINAL MISCHIEF"]:
        weight = 5
    elif current in ["HARRASSMENT-OTHER", "HARRASSMENT BY COMUN/ADDRESS"]:
        weight = 10
    elif current=="MURDER/NON-NEG/MANSLTR-OTHER":
        weight = 20
    else:
        weight = 2
    
    # if a key exists for that neighborhood in the dictionary then the weight is added to the current value related to the key otherwise a new key is created for the neighborhood
    if neighbrhd in count:
        count[neighbrhd] = count[neighbrhd] + weight
    else:
        count[neighbrhd] = weight
    
print(count)
# Out:
# {'North Shore': 14480, 'Upper Lawrenceville': 6728, 'Northview Heights': 11786, 'Golden Triangle/Civic Arena': 18249, 'South Side Flats': 72219, 'Elliott': 10819, 'Homewood North': 27237, 'South Side Slopes': 17057, 'Carrick': 50504, 'South Oakland': 9132, nan: 16606, 'Bloomfield': 36099, 'Beechview': 22859, 'Bluff': 17236, 'Strip District': 13370, 'Mount Washington': 31220, 'East Carnegie': 1883, 'Crafton Heights': 12053, 'Marshall-Shadeland': 23607, 'East Liberty': 35074, 'East Allegheny': 21613, 'Friendship': 7264, 'Arlington': 9851, 'Central Northside': 3507, 'Spring Hill-City View': 10824, 'Brighton Heights': 26392, 'Westwood': 6820, 'East Hills': 21899, 'Brookline': 31594, 'South Shore': 3983, 'Lower Lawrenceville': 10243, 'Bedford Dwellings': 12372, 'Troy Hill-Herrs Island': 1007, 'Central Oakland': 19794, 'Garfield': 13797, 'West End': 3512, 'West Oakland': 7833, 'Central Lawrenceville': 17473, 'Lincoln-Lemington-Belmar': 28261, 'Sheraden': 24986, 'Beltzhoover': 8261, 'Outside City': 5860, 'Squirrel Hill South': 31098, 'North Oakland': 19138, 'Allentown': 21622, 'Perry North': 13752, 'Homewood South': 29059, 'Shadyside': 35413, 'Manchester': 8312, 'Squirrel Hill North': 15463, 'Regent Square': 2681, 'Homewood West': 11419, 'Allegheny Center': 13579, 'Highland Park': 18343, 'Middle Hill': 16599, 'Overbrook': 8813, 'Hazelwood': 23181, 'Greenfield': 14729, 'Morningside': 6277, 'Knoxville': 27070, 'Point Breeze': 13319, 'Duquesne Heights': 4498, 'Perry South': 17677, 'California-Kirkbride': 6643, 'Banksville': 6654, 'Point Breeze North': 10322, 'Bon Air': 4639, 'Polish Hill': 4022, 'Lincoln Place': 6948, 'Fineview': 7083, 'Spring Garden': 3927, 'Larimer': 15378, 'Esplen': 2575, 'Terrace Village': 6555, 'Allegheny West': 4210, 'Crawford-Roberts': 16830, 'Windgap': 3853, 'Stanton Heights': 7929, 'Glen Hazel': 3753, 'Upper Hill': 8508, 'Hays': 2286, 'Ridgemont': 1226, 'Oakwood': 2513, 'Outside State': 1006, 'Chateau': 8167, 'Swisshelm Park': 1980, 'Outside County': 598, 'Fairywood': 3359, 'Chartiers City': 1315, 'Arlington Heights': 2890, 'St. Clair': 2840, 'Summer Hill': 2371, 'Mt. Oliver Neighborhood': 516, 'New Homestead': 1432, 'Mt. Oliver Boro': 405, 'Central Business District': 78026, 'Troy Hill': 8251, 'Central North Side': 12914, 'Mount Oliver': 2490}

# %%
# the dictionary is converted into a Series and then converted into a DataFrame with a labeled column for the weight which is shown in relation to its neighborhood key
countS = pd.Series(count)
countDF = pd.DataFrame(countS, columns=["WEIGHT"])
countDF.head(20)
# Out:
#                              WEIGHT
# North Shore                   14480
# Upper Lawrenceville            6728
# Northview Heights             11786
# Golden Triangle/Civic Arena   18249
# South Side Flats              72219
# Elliott                       10819
# Homewood North                27237
# South Side Slopes             17057
# Carrick                       50504
# South Oakland                  9132
# NaN                           16606
# Bloomfield                    36099
# Beechview                     22859
# Bluff                         17236
# Strip District                13370
# Mount Washington              31220
# East Carnegie                  1883
# Crafton Heights               12053
# Marshall-Shadeland            23607
# East Liberty                  35074

# %%
# the weight values are sorted and shown in ascending order to show the safest neighborhoods
countDF.sort_values(by="WEIGHT", ascending=False, ignore_index=False).head(20)
# Out:
#                            WEIGHT
# Central Business District   78026
# South Side Flats            72219
# Carrick                     50504
# Bloomfield                  36099
# Shadyside                   35413
# East Liberty                35074
# Brookline                   31594
# Mount Washington            31220
# Squirrel Hill South         31098
# Homewood South              29059
# Lincoln-Lemington-Belmar    28261
# Homewood North              27237
# Knoxville                   27070
# Brighton Heights            26392
# Sheraden                    24986
# Marshall-Shadeland          23607
# Hazelwood                   23181
# Beechview                   22859
# East Hills                  21899
# Allentown                   21622

# %%
# all the weights and paired neighborhoods are shown on the bar graph
countDF.plot.bar()

# %%
# a final DataFrame is created which only contains the top 10 safest neighborhoods or the 10 neighborhoods with the smallest weight value and they are displayed on a bar graph
finalNeighborhoods = countDF.sort_values(by="WEIGHT", ascending=True, ignore_index=False).head(10).copy()
finalNeighborhoods.plot.bar()

# %% [markdown]
# ### Conclusion:
#
# Through going through all of the crime incidents given in the original data set and creating a weight value based on the severity of all the incidents that have occurred for each neighborhood, I was able to find the top 10 safest neighborhoods or the ten neighborhoods that had the smallest weights. In conclusion, the best neighborhood in Pittsburgh is Mt. Oliver Boro since it had the smallest weight of 405 and is considered the safest based on my data of recorded incidents. However, personally my favorite neighborhood is Squirrel Hill South because of how ideal the neighborhood is for a residential area. The location is pretty central where it is close by to a couple of schools in addition to being right by Waterfront which is a large shopping center. Even though neighborhood is a little expensive, it is the perfect place to raise a family in a more suburban setting while not leaving the city.
