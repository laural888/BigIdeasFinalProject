# %% [markdown]
# # The Best Neighborhood in Pittsburgh based on Education

# %%
import pandas as pd

enrollment = pd.read_csv("https://data.wprdc.org/dataset/27b6eef7-8825-4cc4-8b48-52c17ac80d37/resource/7b0660d1-c812-496d-ab0a-8560902e9e70/download/neighborhood_school_enrollment.csv")
enrollment.head()
# Out:
#        neighborhood                       school  enrolled_students
# 0  Allegheny Center                        Other                 50
# 1  Allegheny Center       PITTSBURGH KING PreK-8                 34
# 2         Allentown                        Other                 96
# 3         Allentown  PITTSBURGH GRANDVIEW PreK-5                 76
# 4         Allentown   PITTSBURGH SOUTH HILLS 6-8                 50

# %%
enrollment.groupby("neighborhood").sum()
# Out:
#                      enrolled_students
# neighborhood
# Allegheny Center                    84
# Allentown                          289
# Arlington                          186
# Arlington Heights                   27
# Banksville                         180
# ...                                ...
# West End                            28
# West Oakland                        54
# Westwood                           269
# Wilkinsburg Borough                305
# Windgap                            110
#
# [87 rows x 1 columns]

# %%
feeder = pd.read_csv("https://data.wprdc.org/dataset/27b6eef7-8825-4cc4-8b48-52c17ac80d37/resource/643511e3-e99a-4e2a-94a4-033ddb944e94/download/feeder_enrollment.csv")
feeder.head()
# Out:
#                               school  attending_feeder  attending_nonfeeder  \
# 0  PITTSBURGH ALLDERDICE HIGH SCHOOL              1064                  344
# 1        PITTSBURGH ARLINGTON PreK-8               114                  190
# 2        PITTSBURGH ARLINGTON PreK-8               229                  285
# 3             PITTSBURGH ARSENAL 6-8               102                  144
# 4          PITTSBURGH ARSENAL PreK-5               110                  155
#
#    total_with_feeder_status grade_level
# 0                      1408        9-12
# 1                       304         6-8
# 2                       514         K-5
# 3                       246         6-8
# 4                       265         K-5

# %%
feeder.groupby("school").sum()
# Out:
#                                       attending_feeder  attending_nonfeeder  \
# school
# PITTSBURGH ALLDERDICE HIGH SCHOOL                 1064                  344
# PITTSBURGH ARLINGTON PreK-8                        343                  475
# PITTSBURGH ARSENAL 6-8                             102                  144
# PITTSBURGH ARSENAL PreK-5                          110                  155
# PITTSBURGH BANKSVILLE K-5                          112                   46
# PITTSBURGH BEECHWOOD PreK-5                        210                   61
# PITTSBURGH BRASHEAR HIGH SCHOOL                    876                  365
# PITTSBURGH BROOKLINE PreK-8                        383                  160
# PITTSBURGH CARRICK HIGH SCHOOL                     654                  504
# PITTSBURGH COLFAX K-8                              792                  164
# PITTSBURGH CONCORD K-5                             284                   87
# ...

# %% [markdown]
# (Look into what is known about the neighborhoods)
